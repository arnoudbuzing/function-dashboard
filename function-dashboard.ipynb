# %% [markdown]
# # test

# %%
from package_tools import info

# %%
obj = info.package('hypernetx')

# %%
obj

# %%
obj.module_list()
# Out:
# [('algorithms',
#   <module 'hypernetx.algorithms' from '/Users/arnoudb/function-dashboard/.venv/lib/python3.12/site-packages/hypernetx/algorithms/__init__.py'>),
#  ('classes',
#   <module 'hypernetx.classes' from '/Users/arnoudb/function-dashboard/.venv/lib/python3.12/site-packages/hypernetx/classes/__init__.py'>),
#  ('drawing',
#   <module 'hypernetx.drawing' from '/Users/arnoudb/function-dashboard/.venv/lib/python3.12/site-packages/hypernetx/drawing/__init__.py'>),
#  ('exception',
#   <module 'hypernetx.exception' from '/Users/arnoudb/function-dashboard/.venv/lib/python3.12/site-packages/hypernetx/exception.py'>),
#  ('read_write',
#   <module 'hypernetx.read_write' from '/Users/arnoudb/function-dashboard/.venv/lib/python3.12/site-packages/hypernetx/read_write.py'>),
#  ('reports',
#   <module 'hypernetx.reports' from '/Users/arnoudb/function-dashboard/.venv/lib/python3.12/site-packages/hypernetx/reports/__init__.py'>),
#  ('utils',
# ...

# %%
obj.get_package_info()
# Out:
# {'hypernetx': [{'hypernetx.algorithms': [{'hypernetx.algorithms.contagion': [],
#      'classes': ['Counter', '_ListDict_', 'defaultdict'],
#      'functions': [<function hypernetx.algorithms.contagion.Gillespie_SIR(H, tau, gamma, transmission_function=<function threshold at 0x147a260c0>, initial_infecteds=None, initial_recovereds=None, rho=None, tmin=0, tmax=inf, **args)>,
#       <function hypernetx.algorithms.contagion.Gillespie_SIS(H, tau, gamma, transmission_function=<function threshold at 0x147a260c0>, initial_infecteds=None, rho=None, tmin=0, tmax=inf, return_full_data=False, sim_kwargs=None, **args)>,
#       <function hypernetx.algorithms.contagion.collective_contagion(node, status, edge)>,
#       <function hypernetx.algorithms.contagion.contagion_animation(fig, H, transition_events, node_state_color_dict, edge_state_color_dict, node_radius=1, fps=1)>,
# ...

# %%
import scipy
